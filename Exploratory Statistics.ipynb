# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Import titanic dataset. Don't download, use Kaggle integration directly:

# %%
tit = df = sns.load_dataset('titanic')
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 2. Plot the count distribution (Bernoulli) of survival  (sns.countplot)

# %%
bernoullisurvival = sns.countplot(x="survived", data=tit)

# %% [markdown]
# # 3. Separate this distribution now also by Gender (sns.catplot). Experiment with kind and hue arguments

# %%
sns.catplot(x="sex",y="survived",hue="pclass",kind="bar", data=tit)

# %% [markdown]
# # 4. Plot SibSp vs Survived per gender and Pclass using sns.catplot

# %%
sns.catplot(x="sibsp", y="survived", kind="bar",hue='pclass', data=tit);

# %% [markdown]
# # Plot the distribution of fare for each Pclass, color by Survived, use sns.boxplot

# %%
sns.boxplot(x="pclass",y="fare",data=tit)

# %% [markdown]
# # Explain what you observed in your own words.

# %% [markdown]
# __DISTPLOT__:
#     seaborn.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None)
#
#
# Displot by default have histograms and kernel density estimate.
# $$x = np.random.randn(100)$$
# $$ax = sns.distplot(x)$$
#
# When this is used we get a histogram and KDE
#
# $$ax = sns.distplot(x, rug=True, hist=False)$$
#
# This line clearely explains that when the hist is given false in the following output there will be no histogram in the graph instead we get rug plot for each of our data.
#
# $$from scipy.stats import norm$$
# $$ax = sns.distplot(x, fit=norm, kde=False)$$
#
# To fit a parametric distribution to a dataset and visually evaluate how closely it corresponds to the observed data.
#
# $$ax = sns.distplot(x, vertical=True)$$
#
# It gives the follwing graph in vertical format
#
# $$sns.set_color_codes()$$
# $$ax = sns.distplot(x, color="y")$$
#
# It changes the color attribute to be yellow for the Histogram and fthe KDE
#
#  $$ax = sns.distplot(x, rug=True, rugkws={"color": "g"},$$
#                  $$kdekws={"color": "k", "lw": 3 "label": "KDE"},$$
#                   $$histkws={"histtype": "step", "linewidth": 3,
#                              "alpha": 1, "color": "g"})$$
#
#  Here we are aiming to obtain rug plor and we have clearley mentioned its color.In the next step we are defining the color attribute and the label for the KDE. The final step is to achieve the histogram graph dor which we are mentioning the linewidth,color and here the alpha helps to makes the bars semi-translucent and right level of transparency.

# %% [markdown]
# __BOX PLOT:__<br>
#     seaborn.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)
#
# A bloxplot displays the range and distribution of data along the number line.box plots include an additional character to represent the mean of the data.A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).

# %% [markdown]
# __Frequency table or contingency table:__<br>
# A contingency table, sometimes called a two-way frequency table, is a tabular mechanism with at least two rows and two columns used in statistics to present categorical data in terms of frequency counts.They provide a basic picture of the interrelation between the two variables and can help find interactions between them.
#
# __univariate distributions:__<br>
# A univariate plot shows the data and summarizes its distribution.univariate distribution is a probability distribution of only one random variable
#
# __Bivariate distributions:__<br>
# It is the probability that a certain event will occur when there are two independent random variables.It doesn't have a standard look
#
# __Visualizing pairwise relationships in a dataset:__<br>
# Seaborn has the pairplot method through which we can create a matrix of plots (or subplots) using all or specific variables from the dataset.

# %% [markdown]
# __Example for Visualizing pairwise relationships in a dataset:__

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 
np.random.seed(42)
var1 = np.random.rand(2000)
np.random.seed(100)
var2 = np.random.randn(2000)
multi = pd.DataFrame({'Var1': var1, 'Var2': var2})
with sns.color_palette("summer"):
    sns.pairplot(multi)
plt.show()
